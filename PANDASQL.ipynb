# %% [markdown]
# # SQL

# %%
import pandas as pd

# %%
A = pd.read_csv("/Users/kundannavneet/Desktop/classworkr/EMP.csv")

# %%
A
# Out:
#      Unnamed: 0  EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  \
# 0             1          100       Steven         King     SKING
# 1             2          101        Neena      Kochhar  NKOCHHAR
# 2             3          102          Lex      De Haan   LDEHAAN
# 3             4          103    Alexander       Hunold   AHUNOLD
# 4             5          103    Alexander       Hunold   AHUNOLD
# 5             6          104        Bruce        Ernst    BERNST
# 6             7          105        David       Austin   DAUSTIN
# 7             8          106        Valli    Pataballa  VPATABAL
# 8             9          107        Diana      Lorentz  DLORENTZ
# 9            10          108        Nancy    Greenberg  NGREENBE
# 10           11          109       Daniel       Faviet   DFAVIET
# 11           12          110         John         Chen     JCHEN
# 12           13          111       Ismael      Sciarra  ISCIARRA
# ...

# %%
import pandasql as ps

# %%
ps.sqldf("select * from A",locals())
# Out:
#      Unnamed: 0  EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  \
# 0             1          100       Steven         King     SKING
# 1             2          101        Neena      Kochhar  NKOCHHAR
# 2             3          102          Lex      De Haan   LDEHAAN
# 3             4          103    Alexander       Hunold   AHUNOLD
# 4             5          103    Alexander       Hunold   AHUNOLD
# 5             6          104        Bruce        Ernst    BERNST
# 6             7          105        David       Austin   DAUSTIN
# 7             8          106        Valli    Pataballa  VPATABAL
# 8             9          107        Diana      Lorentz  DLORENTZ
# 9            10          108        Nancy    Greenberg  NGREENBE
# 10           11          109       Daniel       Faviet   DFAVIET
# 11           12          110         John         Chen     JCHEN
# 12           13          111       Ismael      Sciarra  ISCIARRA
# ...

# %%
ps.sqldf("select FIRST_NAME from A where FIRST_NAME LIKE 'S%'",locals())
# Out:
#    FIRST_NAME
# 0      Steven
# 1      Shelli
# 2       Sigal
# 3      Shanta
# 4      Steven
# 5     Stephen
# 6      Sarath
# 7      Sundar
# 8     Sundita
# 9       Sarah
# 10     Samuel
# 11      Susan
# 12    Shelley

# %%
ps.sqldf("select * from A where FIRST_NAME LIKE 'S%'",locals())
# Out:
#     Unnamed: 0  EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  \
# 0            1          100     Steven      King     SKING
# 1           18          116     Shelli     Baida    SBAIDA
# 2           19          117      Sigal    Tobias   STOBIAS
# 3           25          123     Shanta   Vollman  SVOLLMAN
# 4           30          128     Steven    Markle   SMARKLE
# 5           40          138    Stephen    Stiles   SSTILES
# 6           63          161     Sarath    Sewall   SSEWALL
# 7           68          166     Sundar      Ande     SANDE
# 8           75          173    Sundita     Kumar    SKUMAR
# 9           94          192      Sarah      Bell     SBELL
# 10          96          194     Samuel    McCain   SMCCAIN
# 11         105          203      Susan    Mavris   SMAVRIS
# 12         107          205    Shelley   Higgins  SHIGGINS
#
#           PHONE_NUMBER  HIRE_DATE    JOB_ID  SALARY  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
ps.sqldf("select * from A where SALARY>5000 and SALARY<10000",locals())
# Out:
#     Unnamed: 0  EMPLOYEE_ID   FIRST_NAME   LAST_NAME     EMAIL  \
# 0            4          103    Alexander      Hunold   AHUNOLD
# 1            5          103    Alexander      Hunold   AHUNOLD
# 2            6          104        Bruce       Ernst    BERNST
# 3           11          109       Daniel      Faviet   DFAVIET
# 4           12          110         John        Chen     JCHEN
# 5           13          111       Ismael     Sciarra  ISCIARRA
# 6           14          112  Jose Manuel       Urman   JMURMAN
# 7           15          113         Luis        Popp     LPOPP
# 8           22          120      Matthew       Weiss    MWEISS
# 9           23          121         Adam       Fripp    AFRIPP
# 10          24          122        Payam    Kaufling  PKAUFLIN
# 11          25          123       Shanta     Vollman  SVOLLMAN
# 12          26          124        Kevin     Mourgos  KMOURGOS
# 13          53          151        David   Bernstein  DBERNSTE
# ...

# %%
S = ps.sqldf("select * from A where SUBSTR(FIRST_NAME,1,1)='S'",locals())

# %%
S
# Out:
#     Unnamed: 0  EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  \
# 0            1          100     Steven      King     SKING
# 1           18          116     Shelli     Baida    SBAIDA
# 2           19          117      Sigal    Tobias   STOBIAS
# 3           25          123     Shanta   Vollman  SVOLLMAN
# 4           30          128     Steven    Markle   SMARKLE
# 5           40          138    Stephen    Stiles   SSTILES
# 6           63          161     Sarath    Sewall   SSEWALL
# 7           68          166     Sundar      Ande     SANDE
# 8           75          173    Sundita     Kumar    SKUMAR
# 9           94          192      Sarah      Bell     SBELL
# 10          96          194     Samuel    McCain   SMCCAIN
# 11         105          203      Susan    Mavris   SMAVRIS
# 12         107          205    Shelley   Higgins  SHIGGINS
#
#           PHONE_NUMBER  HIRE_DATE    JOB_ID  SALARY  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
ps.sqldf("select SUM(SALARY),DEPARTMENT_ID from A group by DEPARTMENT_ID",locals())
# Out:
#     SUM(SALARY)  DEPARTMENT_ID
# 0          7000            NaN
# 1          4400           10.0
# 2         19000           20.0
# 3         24900           30.0
# 4          6500           40.0
# 5        156400           50.0
# 6         37800           60.0
# 7         10000           70.0
# 8        304500           80.0
# 9         58000           90.0
# 10        51600          100.0
# 11        20300          110.0

# %%
ps.sqldf("select SUM(SALARY),JOB_ID from A group by JOB_ID",locals())
# Out:
#     SUM(SALARY)      JOB_ID
# 0          8300  AC_ACCOUNT
# 1         12000      AC_MGR
# 2          4400     AD_ASST
# 3         24000     AD_PRES
# 4         34000       AD_VP
# 5         39600  FI_ACCOUNT
# 6         12000      FI_MGR
# 7          6500      HR_REP
# 8         37800     IT_PROG
# 9         13000      MK_MAN
# 10         6000      MK_REP
# 11        10000      PR_REP
# 12        13900    PU_CLERK
# 13        11000      PU_MAN
# 14        61000      SA_MAN
# 15       250500      SA_REP
# 16        64300    SH_CLERK
# 17        55700    ST_CLERK
# 18        36400      ST_MAN

# %%
ps.sqldf("select MAX(SALARY),JOB_ID from A group by JOB_ID",locals())
# Out:
#     MAX(SALARY)      JOB_ID
# 0          8300  AC_ACCOUNT
# 1         12000      AC_MGR
# 2          4400     AD_ASST
# 3         24000     AD_PRES
# 4         17000       AD_VP
# 5          9000  FI_ACCOUNT
# 6         12000      FI_MGR
# 7          6500      HR_REP
# 8          9000     IT_PROG
# 9         13000      MK_MAN
# 10         6000      MK_REP
# 11        10000      PR_REP
# 12         3100    PU_CLERK
# 13        11000      PU_MAN
# 14        14000      SA_MAN
# 15        11500      SA_REP
# 16         4200    SH_CLERK
# 17         3600    ST_CLERK
# 18         8200      ST_MAN

# %%
ps.sqldf("select MAX(SALARY),DEPARTMENT_ID from A group by DEPARTMENT_ID",locals())
# Out:
#     MAX(SALARY)  DEPARTMENT_ID
# 0          7000            NaN
# 1          4400           10.0
# 2         13000           20.0
# 3         11000           30.0
# 4          6500           40.0
# 5          8200           50.0
# 6          9000           60.0
# 7         10000           70.0
# 8         14000           80.0
# 9         24000           90.0
# 10        12000          100.0
# 11        12000          110.0

# %% [markdown]
# # JOIN TWO VARIABLES

# %%
sayo = pd.read_csv("/Users/kundannavneet/Desktop/ml/join1.csv")

# %%
sayo
# Out:
#    Unnamed: 0  eid       fn        ln   sal
# 0           0  101    nakul      jain  4000
# 1           1  102  swapnil  saratkar  5000
# 2           2  103      raj      heda  6000

# %%
sayo2 = pd.read_csv("/Users/kundannavneet/Desktop/ml/join2.csv")

# %%
sayo2
# Out:
#    Unnamed: 0  eid state
# 0           0  101    mh
# 1           1  102   goa

# %%
ps.sqldf("select * from sayo join sayo2 on (sayo.eid=sayo2.eid)",locals())
# Out:
#    Unnamed: 0  eid       fn        ln   sal  Unnamed: 0  eid state
# 0           0  101    nakul      jain  4000           0  101    mh
# 1           1  102  swapnil  saratkar  5000           1  102   goa

# %%
ps.sqldf("select * from sayo left outer join sayo2 on (sayo.eid=sayo2.eid)",locals())
# Out:
#    Unnamed: 0  eid       fn        ln   sal  Unnamed: 0    eid state
# 0           0  101    nakul      jain  4000         0.0  101.0    mh
# 1           1  102  swapnil  saratkar  5000         1.0  102.0   goa
# 2           2  103      raj      heda  6000         NaN    NaN  None

# %%
ps.sqldf("select FIRST_NAME from A where FIRST_NAME LIKE '%s'",locals())
# Out:
#   FIRST_NAME
# 0       Luis
# 1      James
# 2      James
# 3     Curtis
# 4    Charles
# 5     Alexis
# 6    Douglas

# %%
ps.sqldf("select COUNT(SALARY) from A",locals())
# Out:
#    COUNT(SALARY)
# 0            108

# %% [markdown]
# # MYSQL AGRREGATE FUNCTIONS
# 1.SUM
# 2.AVG
# 3.MAX
# 4.MIN
# 5.COUNT
# 6.DISTINCT

# %% [markdown]
# # JOINS

# %% [markdown]
# # https://www.geeksforgeeks.org/sql-join-set-1-inner-left-right-and-full-joins/
